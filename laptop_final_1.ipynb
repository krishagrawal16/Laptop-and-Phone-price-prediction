# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %%
df=pd.read_csv('Laptops Price Dataset_exported.csv')

# %%
df
# Out:
#                                                  Laptop       Status   Brand
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus  \
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laptop        2160 non-null   object
#  1   Status        2160 non-null   object
#  2   Brand         2160 non-null   object
#  3   Model         2160 non-null   object
#  4   CPU           2160 non-null   object
#  5   RAM           2160 non-null   int64
#  6   Storage       2160 non-null   int64
#  7   Storage type  2118 non-null   object
#  8   GPU           789 non-null    object
#  9   Screen        2160 non-null   float64
#  10  Touch         2160 non-null   object
#  11  Final Price   2160 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 202.6+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['Laptop'],inplace=True)

# %%
df
# Out:
#            Status   Brand       Model                CPU  RAM  Storage
# 0             New    Asus  ExpertBook      Intel Core i5    8      512  \
# 1             New  Alurin          Go      Intel Celeron    8      256
# 2             New    Asus  ExpertBook      Intel Core i3    8      256
# 3             New     MSI      Katana      Intel Core i7   16     1000
# 4             New      HP         15S      Intel Core i5   16      512
# ...           ...     ...         ...                ...  ...      ...
# 2155  Refurbished   Razer       Blade      Intel Core i7   16     1000
# 2156  Refurbished   Razer       Blade      Intel Core i7   16     1000
# 2157  Refurbished   Razer       Blade      Intel Core i7   32     1000
# 2158  Refurbished   Razer        Book  Intel Evo Core i7   16     1000
# 2159  Refurbished   Razer        Book  Intel Evo Core i7   16      256
#
#      Storage type       GPU  Screen Touch  Final Price
# 0             SSD       NaN    15.6    No      1009.00
# ...

# %%
df['CPU'].value_counts()
# Out:
# CPU
# Intel Core i7            710
# Intel Core i5            535
# AMD Ryzen 7              156
# Intel Core i3            130
# AMD Ryzen 5              127
# Intel Core i9             94
# Intel Celeron             94
# Intel Evo Core i7         82
# AMD Ryzen 9               44
# AMD Ryzen 3               44
# Intel Evo Core i5         30
# Apple M2                  28
# AMD 3020e                 13
# Apple M2 Pro              13
# Apple M1                  11
# AMD Athlon                10
# Intel Pentium             10
# Apple M1 Pro               7
# Intel Core M3              5
# AMD 3015e                  3
# Microsoft SQ1              3
# Qualcomm Snapdragon 7      3
# AMD Radeon 9               2
# Qualcomm Snapdragon 8      2
# Intel Evo Core i9          1
# Mediatek MT8183            1
# AMD 3015Ce                 1
# AMD Radeon 5               1
# Name: count, dtype: int64

# %%
df["Status"]=df["Status"].str.replace("New","1")
df["Status"]=df["Status"].str.replace("Refurbished","0")
df.rename(columns={'Status':'Status(New)'}, inplace=True)

# %%
df["Status(New)"]=df["Status(New)"].astype('int64')

# %%
df
# Out:
#       Status(New)   Brand       Model                CPU  RAM  Storage
# 0               1    Asus  ExpertBook      Intel Core i5    8      512  \
# 1               1  Alurin          Go      Intel Celeron    8      256
# 2               1    Asus  ExpertBook      Intel Core i3    8      256
# 3               1     MSI      Katana      Intel Core i7   16     1000
# 4               1      HP         15S      Intel Core i5   16      512
# ...           ...     ...         ...                ...  ...      ...
# 2155            0   Razer       Blade      Intel Core i7   16     1000
# 2156            0   Razer       Blade      Intel Core i7   16     1000
# 2157            0   Razer       Blade      Intel Core i7   32     1000
# 2158            0   Razer        Book  Intel Evo Core i7   16     1000
# 2159            0   Razer        Book  Intel Evo Core i7   16      256
#
#      Storage type       GPU  Screen Touch  Final Price
# 0             SSD       NaN    15.6    No      1009.00
# ...

# %%
df=df.dropna(subset=['Storage type'])

# %%
df["Storage type"]=df["Storage type"].str.replace("SSD","1")
df["Storage type"]=df["Storage type"].str.replace("eMMC","0")
df.rename(columns={'Storage type':'Storage type(SSD)'}, inplace=True)
df['Storage type(SSD)']=df['Storage type(SSD)'].astype('int64')
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_10028\22871579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Storage type"]=df["Storage type"].str.replace("SSD","1")
# C:\Users\krish\AppData\Local\Temp\ipykernel_10028\22871579.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Storage type"]=df["Storage type"].str.replace("eMMC","0")
# C:\Users\krish\AppData\Local\Temp\ipykernel_10028\22871579.py:3: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#       Status(New)   Brand       Model                CPU  RAM  Storage
# 0               1    Asus  ExpertBook      Intel Core i5    8      512  \
# 1               1  Alurin          Go      Intel Celeron    8      256
# 2               1    Asus  ExpertBook      Intel Core i3    8      256
# 3               1     MSI      Katana      Intel Core i7   16     1000
# 4               1      HP         15S      Intel Core i5   16      512
# ...           ...     ...         ...                ...  ...      ...
# 2155            0   Razer       Blade      Intel Core i7   16     1000
# 2156            0   Razer       Blade      Intel Core i7   16     1000
# 2157            0   Razer       Blade      Intel Core i7   32     1000
# 2158            0   Razer        Book  Intel Evo Core i7   16     1000
# 2159            0   Razer        Book  Intel Evo Core i7   16      256
#
#       Storage type(SSD)       GPU  Screen Touch  Final Price
# ...

# %%
df["Touch"]=df["Touch"].str.replace("Yes","1")
df["Touch"]=df["Touch"].str.replace("No","0")
df['Touch']=df['Touch'].astype('int64')
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_10028\2179726684.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Touch"]=df["Touch"].str.replace("Yes","1")
# C:\Users\krish\AppData\Local\Temp\ipykernel_10028\2179726684.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Touch"]=df["Touch"].str.replace("No","0")
# C:\Users\krish\AppData\Local\Temp\ipykernel_10028\2179726684.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import seaborn as sns
sns.distplot(df['Final Price'])
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_10028\2300873921.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Final Price'])
# <Axes: xlabel='Final Price', ylabel='Density'>

# %%
df=df.fillna({'GPU':'no'})

# %%
value_count=df['CPU'].value_counts()

# %%
value_count
# Out:
# CPU
# Intel Core i7            702
# Intel Core i5            520
# AMD Ryzen 7              155
# Intel Core i3            128
# AMD Ryzen 5              127
# Intel Core i9             94
# Intel Celeron             85
# Intel Evo Core i7         82
# AMD Ryzen 3               44
# AMD Ryzen 9               44
# Intel Evo Core i5         30
# Apple M2                  28
# AMD 3020e                 13
# Apple M2 Pro              13
# Apple M1                  11
# AMD Athlon                 9
# Intel Pentium              9
# Apple M1 Pro               7
# AMD 3015e                  3
# Qualcomm Snapdragon 7      3
# Microsoft SQ1              3
# AMD Radeon 9               2
# Intel Core M3              2
# Intel Evo Core i9          1
# Mediatek MT8183            1
# AMD 3015Ce                 1
# Qualcomm Snapdragon 8      1
# Name: count, dtype: int64

# %%
to_remove = value_count[value_count <= 6].index

# %%
df = df[~df.CPU.isin(to_remove)]

# %%
df
# Out:
#       Status(New)   Brand       Model                CPU  RAM  Storage
# 0               1    Asus  ExpertBook      Intel Core i5    8      512  \
# 1               1  Alurin          Go      Intel Celeron    8      256
# 2               1    Asus  ExpertBook      Intel Core i3    8      256
# 3               1     MSI      Katana      Intel Core i7   16     1000
# 4               1      HP         15S      Intel Core i5   16      512
# ...           ...     ...         ...                ...  ...      ...
# 2155            0   Razer       Blade      Intel Core i7   16     1000
# 2156            0   Razer       Blade      Intel Core i7   16     1000
# 2157            0   Razer       Blade      Intel Core i7   32     1000
# 2158            0   Razer        Book  Intel Evo Core i7   16     1000
# 2159            0   Razer        Book  Intel Evo Core i7   16      256
#
#       Storage type(SSD)       GPU  Screen  Touch  Final Price
# ...

# %%
value_count=df['GPU'].value_counts()

# %%
to_remove = value_count[value_count<=9].index

# %%
df = df[~df.GPU.isin(to_remove)]

# %%
df['Screen'].value_counts()
# Out:
# Screen
# 15.6    966
# 14.0    368
# 17.3    148
# 16.0    144
# 13.3    123
# 16.1     42
# 17.0     29
# 15.0     20
# 13.0     20
# 13.5     19
# 13.4     19
# 14.2     14
# 14.1     11
# 13.6     11
# 12.3     10
# 16.2     10
# 11.6      8
# 15.3      8
# 14.4      6
# 10.5      6
# 12.4      5
# 0.0       3
# 18.0      3
# 14.5      3
# 15.4      2
# 13.9      2
# 12.5      1
# 10.1      1
# Name: count, dtype: int64

# %%
df
# Out:
#       Status(New)   Brand       Model                CPU  RAM  Storage
# 0               1    Asus  ExpertBook      Intel Core i5    8      512  \
# 1               1  Alurin          Go      Intel Celeron    8      256
# 2               1    Asus  ExpertBook      Intel Core i3    8      256
# 3               1     MSI      Katana      Intel Core i7   16     1000
# 4               1      HP         15S      Intel Core i5   16      512
# ...           ...     ...         ...                ...  ...      ...
# 2155            0   Razer       Blade      Intel Core i7   16     1000
# 2156            0   Razer       Blade      Intel Core i7   16     1000
# 2157            0   Razer       Blade      Intel Core i7   32     1000
# 2158            0   Razer        Book  Intel Evo Core i7   16     1000
# 2159            0   Razer        Book  Intel Evo Core i7   16      256
#
#       Storage type(SSD)       GPU  Screen  Touch  Final Price
# ...

# %%
value_count=df['Brand'].value_counts()
to_remove = value_count[value_count<=19].index
df = df[~df.Brand.isin(to_remove)]

# %%
#data = df.reindex(columns=["Status(New)", "RAM", "Storage","Storage type(SSD)", "Screen", "Touch","Final Price"])
#corr_matrix=data.corr()
#corr_matrix['Final Price']

# %%
value_count=df['Storage'].value_counts()
to_remove = value_count[value_count<=7].index
df = df[~df.Storage.isin(to_remove)]

# %%
df=df.drop(df[df['Screen'] == 0].index)

# %%
df['Model'].value_counts()
# Out:
# Model
# 15S         114
# IdeaPad     101
# VivoBook     94
# ROG          92
# ThinkPad     81
#            ...
# 14S           1
# LOQ           1
# V17           1
# Notebook      1
# GL75          1
# Name: count, Length: 97, dtype: int64

# %%
sns.barplot(x=df['Brand'],y=df['Final Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['CPU'],y=df['Final Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# from sklearn.preprocessing import LabelEncoder
 #le = LabelEncoder()
 #df['Brand'] = le.fit_transform(df['Brand'])
 #df['Model'] = le.fit_transform(df['Model'])
 #df['CPU'] = le.fit_transform(df['CPU'])
 #df['GPU'] = le.fit_transform(df['GPU'])

# %%
df['RAM'].unique()
# Out:
# array([  8,  16,  32,  12,   4,  64, 128], dtype=int64)

# %%
df['Storage'].unique()
# Out:
# array([ 512,  256, 1000,   64,  128, 2000,  500,   32], dtype=int64)

# %%
df
# Out:
#       Status(New)   Brand       Model                CPU  RAM  Storage
# 0               1    Asus  ExpertBook      Intel Core i5    8      512  \
# 1               1  Alurin          Go      Intel Celeron    8      256
# 2               1    Asus  ExpertBook      Intel Core i3    8      256
# 3               1     MSI      Katana      Intel Core i7   16     1000
# 4               1      HP         15S      Intel Core i5   16      512
# ...           ...     ...         ...                ...  ...      ...
# 2155            0   Razer       Blade      Intel Core i7   16     1000
# 2156            0   Razer       Blade      Intel Core i7   16     1000
# 2157            0   Razer       Blade      Intel Core i7   32     1000
# 2158            0   Razer        Book  Intel Evo Core i7   16     1000
# 2159            0   Razer        Book  Intel Evo Core i7   16      256
#
#       Storage type(SSD)       GPU  Screen  Touch  Final Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1934 entries, 0 to 2159
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Status(New)        1934 non-null   int64
#  1   Brand              1934 non-null   object
#  2   Model              1934 non-null   object
#  3   CPU                1934 non-null   object
#  4   RAM                1934 non-null   int64
#  5   Storage            1934 non-null   int64
#  6   Storage type(SSD)  1934 non-null   int64
#  7   GPU                1934 non-null   object
#  8   Screen             1934 non-null   float64
#  9   Touch              1934 non-null   int64
#  10  Final Price        1934 non-null   float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 181.3+ KB

# %%
sns.distplot(np.log(df['Final Price']))
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_10028\3897261032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Final Price']))
# <Axes: xlabel='Final Price', ylabel='Density'>

# %%
def fetch_model(text):
    if text == '15S' or text == 'IdeaPad' or text == 'VivoBook' or text =='ROG' or text =='ThinkPad'or text =='TUF'or text =='MacBook Pro'or text =='V15'or text =='ZenBook'or text =='ThinkBook'or text =='ExpertBook'or text =='Latitude'or text =='MacBook Air'or text =='Chromebook'or text =='Surface Laptop':
        return text
    else:
         return 'Any other model'

# %%
df['Model'] = df['Model'].apply(fetch_model)

# %%
df['Model'].unique()
# Out:
# array(['ExpertBook', 'Any other model', '15S', 'ThinkPad', 'VivoBook',
#        'V15', 'ROG', 'IdeaPad', 'TUF', 'Chromebook', 'ZenBook',
#        'MacBook Air', 'ThinkBook', 'MacBook Pro', 'Latitude',
#        'Surface Laptop'], dtype=object)

# %%
X = df.drop(columns=['Final Price'])
y = np.log(df['Final Price'])

# %%
X2 = pd.get_dummies(X, columns=['Brand', 'Model', 'CPU', 'GPU'],drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X2,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score,mean_absolute_error
from xgboost import XGBRegressor

# %%
step2 = GradientBoostingRegressor(n_estimators=1000)



step2.fit(X_train,y_train)

y_pred = step2.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8286476358462839
# MAE 0.17627388009967282

# %%
import pickle

pickle.dump(df,open('df_final_2.pkl','wb'))
pickle.dump(step2,open('pipe_final_2.pkl','wb'))
pickle.dump(X_train,open('ohed_2.pkl','wb'))

# %%
df
# Out:
#       Status(New)   Brand            Model                CPU  RAM  Storage
# 0               1    Asus       ExpertBook      Intel Core i5    8      512  \
# 1               1  Alurin  Any other model      Intel Celeron    8      256
# 2               1    Asus       ExpertBook      Intel Core i3    8      256
# 3               1     MSI  Any other model      Intel Core i7   16     1000
# 4               1      HP              15S      Intel Core i5   16      512
# ...           ...     ...              ...                ...  ...      ...
# 2155            0   Razer  Any other model      Intel Core i7   16     1000
# 2156            0   Razer  Any other model      Intel Core i7   16     1000
# 2157            0   Razer  Any other model      Intel Core i7   32     1000
# 2158            0   Razer  Any other model  Intel Evo Core i7   16     1000
# 2159            0   Razer  Any other model  Intel Evo Core i7   16      256
#
# ...
